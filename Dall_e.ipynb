# %% [markdown]
# <a href="https://colab.research.google.com/github/daveboyd777/18S191/blob/master/Dall_e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 44 kB 786 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 146 kB 8.8 MB/s
# ...
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=497888720b94ef0f9c6d42b5c7996975f9b77db3023e682eb9f9288a4cb1e5af
#   Stored in directory: /root/.cache/pip/wheels/4b/92/33/6f57c7aae0b16875267999a50570e81f15eecec577ebe05a2e
# Successfully built openai
# ...

# %%
import os
import openai
from IPython.display import Image
from IPython import display
from base64 import b64decode

openai.api_key = "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"
response = openai.Image.create(
  prompt="river forest swamp with deleted nuclear power plant and exuberant eco-tourists frolicking in river with otters",
  n=1,
  size="512x512",
  response_format="b64_json"
)
image_b64 = response['data'][0]['b64_json']
display.Image(b64decode(image_b64))
